# %%
import bs4 as bs 
import re
import pandas as pd
import numpy as np

'''
1. load html in code
2. tranform to soup
3. strip to only body

4. loop through and grab only:
    
5. 


Output: text file 

'''
# Out:
# '\n1. load html in code\n2. tranform to soup\n3. strip to only body\n\n4. loop through and grab only:\n    \n5. \n\n\nOutput: text file \n\n'

# %%
file_path = "notes/Ego Is the Enemy - Notebook.html"

# %%
f1 = open(file_path, 'r', encoding="utf-8").read()

# %%
soup = bs.BeautifulSoup(f1, features='html.parser')

# %%
soup
# Out:
# <!DOCTYPE html PUBLIC
# "-//W3C//DTD XHTML 1.0 Strict//EN"
# "XHTML1-s.dtd" >
#
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/TR/1999/REC-html-in-xml">
# <head>
# <meta charset="utf-8"/>
# <style>
#         .bodyContainer {
#             font-family: Arial, Helvetica, sans-serif;
#             text-align: center;
#             padding-left: 32px;
#             padding-right: 32px;
#         }
#
#         .notebookFor {
#             font-size: 18px;
#             font-weight: 700;
#             text-align: center;
#             color: rgb(119, 119, 119);
#             margin: 24px 0px 0px;
#             padding: 0px;
#         }
#
#         .bookTitle {
#             font-size: 24px;
#             font-weight: 700;
#             text-align: center;
#             color: #333333;
#             margin-top: 22px;
#             padding: 0px;
#         }
#
#         .authors {
#             font-size: 18px;
#             font-weight: 700;
#             text-align: center;
#             color: rgb(119, 119, 119);
#             margin-top: 22px;
#             margin-bottom: 24px;
#             padding: 0px;
#         }
#
#         .citation {
#             font-size: 18px;
#             font-weight: 500;
#             text-align: center;
#             color: #333333;
#             margin-top: 22px;
#             margin-bottom: 24px;
#             padding: 0px;
#         }
#
#         .sectionHeading {
#             font-size: 24px;
#             font-weight: 700;
#             text-align: left;
#             color: #333333;
#             margin-top: 24px;
#             padding: 0px;
#         }
#
#         .noteHeading {
#             font-size: 18px;
#             font-weight: 700;
#             text-align: left;
#             color: #333333;
#             margin-top: 20px;
#             padding: 0px;
#         }
#
#         .noteText {
#             font-size: 18px;
#             font-weight: 500;
#             text-align: left;
#             color: #333333;
#             margin: 2px 0px 0px;
#             padding: 0px;
#         }
#
#         .highlight_blue {
#             color: rgb(178, 205, 251);
#         }
#
#         .highlight_orange {
#             color: #ffd7ae;
#         }
#
#         .highlight_pink {
#             color: rgb(255, 191, 206);
#         }
#
#         .highlight_yellow {
#             color: rgb(247, 206, 0);
#         }
#
#         .notebookGraphic {
#             margin-top: 10px;
#             text-align: left;
#         }
#
#         .notebookGraphic img {
#             -o-box-shadow:      0px 0px 5px #888;
#             -icab-box-shadow:   0px 0px 5px #888;
#             -khtml-box-shadow:  0px 0px 5px #888;
#             -moz-box-shadow:    0px 0px 5px #888;
#             -webkit-box-shadow: 0px 0px 5px #888;
#             box-shadow:         0px 0px 5px #888;
#             max-width: 100%;
#             height: auto;
#         }
#
#         hr {
#             border: 0px none;
#             height: 1px;
#             background: none repeat scroll 0% 0% rgb(221, 221, 221);
#         }
#         </style>
# <script>
# </script>
# </head>
# <body>
# <div class="bodyContainer">
# <div class="notebookFor">
#                 Notebook Export
#             </div>
# <div class="bookTitle">
#                 Ego Is the Enemy
#             </div>
# <div class="authors">
#                 Holiday, Ryan
#             </div>
# <div class="citation">
# </div>
# <hr/>
# <div class="sectionHeading">
#     THE PAINFUL PROLOGUE
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_orange">orange</span>) - Page xxiv · Location 185
# </div>
# <div class="noteText">
#     We must begin by seeing ourselves and the world in a new way for the first time. Then we must fight to be different and fight to stay different—that’s the hard part. I’m not saying you should repress or crush every ounce of ego in your life—or that doing so is even possible. These are just reminders, moral stories to encourage our better impulses.
# </div><div class="sectionHeading">
#     INTRODUCTION
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_orange">orange</span>) - Page 2 · Location 210
# </div>
# <div class="noteText">
#     The ego we see most commonly goes by a more casual definition: an unhealthy belief in our own importance. Arrogance. Self-centered ambition.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - Page 4 · Location 238
# </div>
# <div class="noteText">
#     “If you start believing in your greatness, it is the death of your creativity.”
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - Page 6 · Location 266
# </div>
# <div class="noteText">
#     Humble in our aspirations Gracious in our success Resilient in our failures
# </div><div class="sectionHeading">
#     PART I: ASPIRE
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - TALK, TALK, TALK &gt; Page 26 · Location 457
# </div>
# <div class="noteText">
#     So what is scarce and rare? Silence. The ability to deliberately keep yourself out of the conversation and subsist without its validation. Silence is the respite of the confident and the strong.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - TALK, TALK, TALK &gt; Page 28 · Location 486
# </div>
# <div class="noteText">
#     The only relationship between work and chatter is that one kills the other.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - TO BE OR TO DO? &gt; Page 35 · Location 569
# </div>
# <div class="noteText">
#     Think about this the next time you face that choice: Do I need this? Or is it really about ego? Are you ready to make the right decision? Or do the prizes still glitter off in the distance? To be or to do—life is a constant roll call.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - BECOME A STUDENT &gt; Page 39 · Location 610
# </div>
# <div class="noteText">
#     mastery. The pretense of knowledge is our most dangerous vice, because it prevents us from getting any better. Studious self-assessment is the antidote.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - BECOME A STUDENT &gt; Page 39 · Location 615
# </div>
# <div class="noteText">
#     Each fighter, to become great, he said, needs to have someone better that they can learn from, someone lesser who they can teach, and someone equal that they can challenge themselves against.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - BECOME A STUDENT &gt; Page 43 · Location 662
# </div>
# <div class="noteText">
#     It’s why the old proverb says, “When student is ready, the teacher appears.”
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - DON’T BE PASSIONATE &gt; Page 47 · Location 705
# </div>
# <div class="noteText">
#     The reality: We hear what we want to hear. We do what we feel like doing, and despite being incredibly busy and working very hard, we accomplish very little. Or worse, find ourselves in a mess we never anticipated.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - DON’T BE PASSIONATE &gt; Page 48 · Location 715
# </div>
# <div class="noteText">
#     Passion typically masks a weakness. Its breathlessness and impetuousness and franticness are poor substitutes for discipline, for mastery, for strength and purpose and perseverance. You need to be able to spot this in others and in yourself, because while the origins of passion may be earnest and good, its effects are comical and then monstrous.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - DON’T BE PASSIONATE &gt; Page 49 · Location 728
# </div>
# <div class="noteText">
#     What humans require in our ascent is purpose and realism. Purpose, you could say, is like passion with boundaries. Realism is detachment and perspective.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - DON’T BE PASSIONATE &gt; Page 49 · Location 731
# </div>
# <div class="noteText">
#     Passion is about. (I am so passionate about ______.) Purpose is to and for. (I must do ______. I was put here to accomplish ______. I am willing to endure ______ for the sake of this.) Actually, purpose deemphasizes the I. Purpose is about pursuing something outside yourself as opposed to pleasuring yourself.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - DON’T BE PASSIONATE &gt; Page 50 · Location 744
# </div>
# <div class="noteText">
#     Passion is form over function. Purpose is function, function, function.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - FOLLOW THE CANVAS STRATEGY &gt; Page 51 · Location 751
# </div>
# <div class="noteText">
#     Great men have almost always shown themselves as ready to obey as they afterwards proved able to command.—LORD MAHON
# </div><div class="noteHeading">
#     Bookmark - FOLLOW THE CANVAS STRATEGY &gt; Page 53 · Location 777
# </div>
# <div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - FOLLOW THE CANVAS STRATEGY &gt; Page 53 · Location 783
# </div>
# <div class="noteText">
#     Find canvases for other people to paint on. Be an anteambulo. Clear the path for the people above you and you will eventually create a path for yourself.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - FOLLOW THE CANVAS STRATEGY &gt; Page 53 · Location 784
# </div>
# <div class="noteText">
#     When you are just starting out, we can be sure of a few fundamental realities: 1) You’re not nearly as good or as important as you think you are; 2) You have an attitude that needs to be readjusted; 3) Most of what you think you know or most of what you learned in books or in school is out of date or wrong.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - FOLLOW THE CANVAS STRATEGY &gt; Page 56 · Location 816
# </div>
# <div class="noteText">
#     Greatness comes from humble beginnings; it comes from grunt work. It means you’re the least important person in the room—until you change that with results.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - FOLLOW THE CANVAS STRATEGY &gt; Page 57 · Location 830
# </div>
# <div class="noteText">
#     Maybe it’s coming up with ideas to hand over to your boss. Find people, thinkers, up-and-comers to introduce them to each other. Cross wires to create new sparks. Find what nobody else wants to do and do it. Find inefficiencies and waste and redundancies. Identify leaks and patches to free up resources for new areas. Produce more than everyone else and give your ideas away
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - RESTRAIN YOURSELF &gt; Page 63 · Location 899
# </div>
# <div class="noteText">
#     Those who have subdued their ego understand that it doesn’t degrade you when others treat you poorly; it degrades them.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - RESTRAIN YOURSELF &gt; Page 64 · Location 913
# </div>
# <div class="noteText">
#     But you’re not able to change the system until after you’ve made it. In the meantime, you’ll have to find some way to make it suit your purposes—even if those purposes are just extra time to develop properly, to learn from others on their dime, to build your base and establish yourself.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - THE DANGER OF EARLY PRIDE &gt; Page 74 · Location 1022
# </div>
# <div class="noteText">
#     Pride blunts the very instrument we need to own in order to succeed: our mind. Our ability to learn, to adapt, to be flexible, to build relationships, all of this is dulled by pride.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - THE DANGER OF EARLY PRIDE &gt; Page 75 · Location 1039
# </div>
# <div class="noteText">
#     Pride is a masterful encroacher. John D. Rockefeller, as a young man, practiced a nightly conversation with himself. “Because you have got a start,” he’d say aloud or write in his diary, “you think you are quite a merchant; look out or you will lose your head—go steady.”
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - THE DANGER OF EARLY PRIDE &gt; Page 78 · Location 1076
# </div>
# <div class="noteText">
#     It isn’t “Don’t boast about what hasn’t happened yet.” It is more directly “Don’t boast.” There’s nothing in it for you.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - WORK, WORK, WORK &gt; Page 82 · Location 1120
# </div>
# <div class="noteText">
#     Fac, si facis. (Do it if you’re going to do it.)
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - WORK, WORK, WORK &gt; Page 83 · Location 1136
# </div>
# <div class="noteText">
#     Every time you sit down to work, remind yourself: I am delaying gratification by doing this. I am passing the marshmallow test. I am earning what my ambition burns for. I am making an investment in myself instead of in my ego. Give yourself a little credit for this choice, but not so much, because you’ve got to get back to the task at hand: practicing, working, improving.
# </div><div class="sectionHeading">
#     PART II: SUCCESS
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - Page 99 · Location 1267
# </div>
# <div class="noteText">
#     “Man is pushed by drives,” Viktor Frankl observed. “But he is pulled by values.” Ruled by or ruling? Which are you?
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - ALWAYS STAY A STUDENT &gt; Page 105 · Location 1334
# </div>
# <div class="noteText">
#     An amateur is defensive. The professional finds learning (and even, occasionally, being shown up) to be enjoyable; they like being challenged and humbled, and engage in education as an ongoing and endless process.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - DON’T TELL YOURSELF A STORY &gt; Page 111 · Location 1400
# </div>
# <div class="noteText">
#     When we are aspiring we must resist the impulse to reverse engineer success from other people’s stories. When we achieve our own, we must resist the desire to pretend that everything unfolded exactly as we’d planned. There was no grand narrative. You should remember—you were there when it happened.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - WHAT’S IMPORTANT TO YOU? &gt; Page 116 · Location 1455
# </div>
# <div class="noteText">
#     All of us waste precious life doing things we don’t like, to prove ourselves to people we don’t respect, and to get things we don’t want. Why do we do this? Well, it should
# </div><div class="noteHeading">
#     Bookmark - ENTITLEMENT, CONTROL, AND PARANOIA &gt; Page 122 · Location 1528
# </div>
# <div class="noteHeading">
#     Bookmark - MEDITATE ON THE IMMENSITY &gt; Page 141 · Location 1754
# </div>
# <div class="sectionHeading">
#     PART III: FAILURE
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - Page 165 · Location 1996
# </div>
# <div class="noteText">
#     Ego loves this notion, the idea that something is “fair” or not. Psychologists call it narcissistic injury when we take personally totally indifferent and objective events. We do that when our sense of self is fragile and dependent on life going our way all the time. Whether what you’re going through is your fault or your problem doesn’t matter, because it’s yours to deal with right now.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - Page 168 · Location 2037
# </div>
# <div class="noteText">
#     The only way out is through.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - ALIVE TIME OR DEAD TIME? &gt; Page 173 · Location 2081
# </div>
# <div class="noteText">
#     Dead time is revived when we use it as an opportunity to do what we’ve long needed to do.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - THE EFFORT IS ENOUGH &gt; Page 177 · Location 2132
# </div>
# <div class="noteText">
#     Doing the right thing was enough. Serving his country, his God, and doing his duty faithfully was all that mattered. Any adversity could be endured and any rewards were considered extra.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - THE EFFORT IS ENOUGH &gt; Page 178 · Location 2145
# </div>
# <div class="noteText">
#     It’s far better when doing good work is sufficient. In other words, the less attached we are to outcomes the better. When fulfilling our own standards is what fills us with pride and self-respect. When the effort—not the results, good or bad—is enough.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - Fight Club MOMENTS &gt; Page 184 · Location 2215
# </div>
# <div class="noteText">
#     1. They almost always came at the hands of some outside force or person. 2. They often involved things we already knew about ourselves, but were too scared to admit. 3. From the ruin came the opportunity for great progress and improvement.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - DRAW THE LINE &gt; Page 192 · Location 2306
# </div>
# <div class="noteText">
#     “If you cannot reasonably hope for a favorable extrication, do not plunge deeper. Have the courage to make a full stop.”
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - DRAW THE LINE &gt; Page 193 · Location 2331
# </div>
# <div class="noteText">
#     “He who fears death will never do anything worthy of a living man,” Seneca once said. Alter that: He who will do anything to avoid failure will almost certainly do something worthy of a failure.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - ALWAYS LOVE &gt; Page 205 · Location 2461
# </div>
# <div class="noteText">
#     The question we must ask for ourselves is: Are we going to be miserable just because other people are?
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - FOR EVERYTHING THAT COMES NEXT, EGO IS THE ENEMY . . . &gt; Page 209 · Location 2501
# </div>
# <div class="noteText">
#     Aspiration leads to success (and adversity). Success creates its own adversity (and, hopefully, new ambitions). And adversity leads to aspiration and more success. It’s an endless loop.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - EPILOGUE &gt; Page 212 · Location 2526
# </div>
# <div class="noteText">
#     training was like sweeping the floor. Just because we’ve done it once, doesn’t mean the floor is clean forever. Every day the dust comes back. Every day we must sweep. The same is true for ego. You would be stunned at what kind of damage dust and dirt can do over time. And how quickly it accumulates and becomes utterly unmanageable.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - EPILOGUE &gt; Page 216 · Location 2578
# </div>
# <div class="noteText">
#     There’s a quote from Bismarck that says, in effect, any fool can learn from experience. The trick is to learn from other people’s experience.
# </div>
# </div>
# </body>
# </html>

# %%
def get_book_details(soup):
    
    book_details = {}
    
    try:
        book_details['Title'] = soup.find('div', {'class': 'bookTitle'}).text.strip()
        book_details['Authors'] = soup.find('div', {'class': 'authors'}).text.strip()
        book_details['Citations']= soup.find('div', {'class': 'citation'}).text.strip()
    except:
        pass
    
    return book_details

# %%
all_divs = soup.findAll('div')
all_divs[5].text
# Out:
# '\n    THE PAINFUL PROLOGUE\n'

# %%
all_divs[6].find_next()
# Out:
# <span class="highlight_orange">orange</span>

# %%
test = all_divs[6].text.strip()
test
# Out:
# 'Highlight(orange) - Page xxiv · Location 185'

# %%
div_class = []

for item in all_divs:
    div_class.append(item['class'][0])

# %%
#unique classes:
#We care about noteHeading, sectionHeading & noteText
set(div_class)
# Out:
# {'authors',
#  'bodyContainer',
#  'bookTitle',
#  'citation',
#  'noteHeading',
#  'noteText',
#  'notebookFor',
#  'sectionHeading'}

# %%
type_pattern = r'(.*)-'
page_pattern = r'Page (.+) ·'
location_pattern = r'Location (\d+)'

# %%
def get_page_location(div_soup):
    
    '''
    Use when div_soup[class] = noteHeading
    
    '''
    
    details = {}  
    
    try:
        details['Type'] = re.findall(type_pattern, div_soup)[0].strip()
    except:
        details['Type'] = -1
    
    try:
        details['Page'] = re.findall(page_pattern, div_soup)[0]  
    except:
        details['Page'] = -1
        
    try:
        details['Location'] = re.findall(location_pattern, div_soup)[0]
    except:
        details['Location'] = -1                                 
    
    return details

# %%
all_divs[6].text.strip()
# Out:
# 'Highlight(orange) - Page xxiv · Location 185'

# %%
get_page_location(all_divs[22].text.strip())
# Out:
# {'Type': 'Highlight(yellow)', 'Page': '39', 'Location': '610'}

# %%
soup.find('div').find_next()
# Out:
# <div class="notebookFor">
#                 Notebook Export
#             </div>

# %%
all_divs = soup.findAll('div')
section = 0

section_headers = {}
section_texts = pd.DataFrame()

current_type = None
current_page = None
current_location = None

for div_tag in all_divs:

    if div_tag['class'][0] == 'sectionHeading':

        section += 1
        section_headers[section] = div_tag.text.strip()
    
    if div_tag['class'][0] == 'noteHeading':
        div_text = div_tag.text.strip() #get text of div
        page_location = get_page_location(div_text) #extract page & location
        
        current_type = page_location['Type']
        current_page = page_location['Page']
        current_location = page_location['Location']
        
        if current_type == 'Bookmark':
            text = pd.Series([section, current_type, '', current_page, current_location],
                index = ['Section', 'Type', 'Text', 'Page', 'Location'])
            section_texts = pd.concat([section_texts, text], axis = 1)
        
        
    if div_tag['class'][0] == 'noteText':
        text = pd.Series([section, current_type, div_tag.text.strip(), current_page, current_location],
                        index = ['Section', 'Type', 'Text', 'Page', 'Location'])
        section_texts = pd.concat([section_texts, text], axis = 1)

# %%
section_headers
# Out:
# {1: 'THE PAINFUL PROLOGUE',
#  2: 'INTRODUCTION',
#  3: 'PART I: ASPIRE',
#  4: 'PART II: SUCCESS',
#  5: 'PART III: FAILURE'}

# %%
section_texts.T
# Out:
#   Section               Type  \
# 0       1  Highlight(orange)
# 0       2  Highlight(orange)
# 0       2  Highlight(yellow)
# 0       2  Highlight(yellow)
# 0       3  Highlight(yellow)
# 0       3  Highlight(yellow)
# 0       3  Highlight(yellow)
# 0       3  Highlight(yellow)
# 0       3  Highlight(yellow)
# 0       3  Highlight(yellow)
# 0       3  Highlight(yellow)
# 0       3  Highlight(yellow)
# 0       3  Highlight(yellow)
# 0       3  Highlight(yellow)
# 0       3  Highlight(yellow)
# 0       3  Highlight(yellow)
# 0       3           Bookmark
# 0       3  Highlight(yellow)
# 0       3  Highlight(yellow)
# 0       3  Highlight(yellow)
# 0       3  Highlight(yellow)
# 0       3  Highlight(yellow)
# 0       3  Highlight(yellow)
# 0       3  Highlight(yellow)
# 0       3  Highlight(yellow)
# 0       3  Highlight(yellow)
# 0       3  Highlight(yellow)
# 0       3  Highlight(yellow)
# 0       4  Highlight(yellow)
# 0       4  Highlight(yellow)
# 0       4  Highlight(yellow)
# 0       4  Highlight(yellow)
# 0       4           Bookmark
# 0       4           Bookmark
# 0       5  Highlight(yellow)
# 0       5  Highlight(yellow)
# 0       5  Highlight(yellow)
# 0       5  Highlight(yellow)
# 0       5  Highlight(yellow)
# 0       5  Highlight(yellow)
# 0       5  Highlight(yellow)
# 0       5  Highlight(yellow)
# 0       5  Highlight(yellow)
# 0       5  Highlight(yellow)
# 0       5  Highlight(yellow)
# 0       5  Highlight(yellow)
#
#                                                 Text  Page Location
# 0  We must begin by seeing ourselves and the worl...  xxiv      185
# 0  The ego we see most commonly goes by a more ca...     2      210
# 0  “If you start believing in your greatness, it ...     4      238
# 0  Humble in our aspirations Gracious in our succ...     6      266
# 0  So what is scarce and rare? Silence. The abili...    26      457
# 0  The only relationship between work and chatter...    28      486
# 0  Think about this the next time you face that c...    35      569
# 0  mastery. The pretense of knowledge is our most...    39      610
# 0  Each fighter, to become great, he said, needs ...    39      615
# 0  It’s why the old proverb says, “When student i...    43      662
# 0  The reality: We hear what we want to hear. We ...    47      705
# 0  Passion typically masks a weakness. Its breath...    48      715
# 0  What humans require in our ascent is purpose a...    49      728
# 0  Passion is about. (I am so passionate about __...    49      731
# 0  Passion is form over function. Purpose is func...    50      744
# 0  Great men have almost always shown themselves ...    51      751
# 0                                                       53      777
# 0  Find canvases for other people to paint on. Be...    53      783
# 0  When you are just starting out, we can be sure...    53      784
# 0  Greatness comes from humble beginnings; it com...    56      816
# 0  Maybe it’s coming up with ideas to hand over t...    57      830
# 0  Those who have subdued their ego understand th...    63      899
# 0  But you’re not able to change the system until...    64      913
# 0  Pride blunts the very instrument we need to ow...    74     1022
# 0  Pride is a masterful encroacher. John D. Rocke...    75     1039
# 0  It isn’t “Don’t boast about what hasn’t happen...    78     1076
# 0   Fac, si facis. (Do it if you’re going to do it.)    82     1120
# 0  Every time you sit down to work, remind yourse...    83     1136
# 0  “Man is pushed by drives,” Viktor Frankl obser...    99     1267
# 0  An amateur is defensive. The professional find...   105     1334
# 0  When we are aspiring we must resist the impuls...   111     1400
# 0  All of us waste precious life doing things we ...   116     1455
# 0                                                      122     1528
# 0                                                      141     1754
# 0  Ego loves this notion, the idea that something...   165     1996
# 0                       The only way out is through.   168     2037
# 0  Dead time is revived when we use it as an oppo...   173     2081
# 0  Doing the right thing was enough. Serving his ...   177     2132
# 0  It’s far better when doing good work is suffic...   178     2145
# 0  1. They almost always came at the hands of som...   184     2215
# 0  “If you cannot reasonably hope for a favorable...   192     2306
# 0  “He who fears death will never do anything wor...   193     2331
# 0  The question we must ask for ourselves is: Are...   205     2461
# 0  Aspiration leads to success (and adversity). S...   209     2501
# 0  training was like sweeping the floor. Just bec...   212     2526
# 0  There’s a quote from Bismarck that says, in ef...   216     2578

# %%
get_page_location(all_divs[32].text.strip())
# Out:
# {'Type': 'Highlight(yellow) ', 'Page': '49', 'Location': '728'}

# %%
for div in all_divs:
    
    if div['class'][0] == 'noteHeading':
        print(div.text.strip())
# Out:
# Highlight(orange) - Page xxiv · Location 185
# Highlight(orange) - Page 2 · Location 210
# Highlight(yellow) - Page 4 · Location 238
# Highlight(yellow) - Page 6 · Location 266
# Highlight(yellow) - TALK, TALK, TALK > Page 26 · Location 457
# Highlight(yellow) - TALK, TALK, TALK > Page 28 · Location 486
# Highlight(yellow) - TO BE OR TO DO? > Page 35 · Location 569
# Highlight(yellow) - BECOME A STUDENT > Page 39 · Location 610
# Highlight(yellow) - BECOME A STUDENT > Page 39 · Location 615
# Highlight(yellow) - BECOME A STUDENT > Page 43 · Location 662
# Highlight(yellow) - DON’T BE PASSIONATE > Page 47 · Location 705
# Highlight(yellow) - DON’T BE PASSIONATE > Page 48 · Location 715
# Highlight(yellow) - DON’T BE PASSIONATE > Page 49 · Location 728
# Highlight(yellow) - DON’T BE PASSIONATE > Page 49 · Location 731
# Highlight(yellow) - DON’T BE PASSIONATE > Page 50 · Location 744
# Highlight(yellow) - FOLLOW THE CANVAS STRATEGY > Page 51 · Location 751
# Bookmark - FOLLOW THE CANVAS STRATEGY > Page 53 · Location 777
# Highlight(yellow) - FOLLOW THE CANVAS STRATEGY > Page 53 · Location 783
# Highlight(yellow) - FOLLOW THE CANVAS STRATEGY > Page 53 · Location 784
# Highlight(yellow) - FOLLOW THE CANVAS STRATEGY > Page 56 · Location 816
# Highlight(yellow) - FOLLOW THE CANVAS STRATEGY > Page 57 · Location 830
# Highlight(yellow) - RESTRAIN YOURSELF > Page 63 · Location 899
# Highlight(yellow) - RESTRAIN YOURSELF > Page 64 · Location 913
# Highlight(yellow) - THE DANGER OF EARLY PRIDE > Page 74 · Location 1022
# Highlight(yellow) - THE DANGER OF EARLY PRIDE > Page 75 · Location 1039
# Highlight(yellow) - THE DANGER OF EARLY PRIDE > Page 78 · Location 1076
# Highlight(yellow) - WORK, WORK, WORK > Page 82 · Location 1120
# Highlight(yellow) - WORK, WORK, WORK > Page 83 · Location 1136
# Highlight(yellow) - Page 99 · Location 1267
# Highlight(yellow) - ALWAYS STAY A STUDENT > Page 105 · Location 1334
# Highlight(yellow) - DON’T TELL YOURSELF A STORY > Page 111 · Location 1400
# Highlight(yellow) - WHAT’S IMPORTANT TO YOU? > Page 116 · Location 1455
# Bookmark - ENTITLEMENT, CONTROL, AND PARANOIA > Page 122 · Location 1528
# Bookmark - MEDITATE ON THE IMMENSITY > Page 141 · Location 1754
# Highlight(yellow) - Page 165 · Location 1996
# Highlight(yellow) - Page 168 · Location 2037
# Highlight(yellow) - ALIVE TIME OR DEAD TIME? > Page 173 · Location 2081
# Highlight(yellow) - THE EFFORT IS ENOUGH > Page 177 · Location 2132
# Highlight(yellow) - THE EFFORT IS ENOUGH > Page 178 · Location 2145
# Highlight(yellow) - Fight Club MOMENTS > Page 184 · Location 2215
# Highlight(yellow) - DRAW THE LINE > Page 192 · Location 2306
# Highlight(yellow) - DRAW THE LINE > Page 193 · Location 2331
# Highlight(yellow) - ALWAYS LOVE > Page 205 · Location 2461
# Highlight(yellow) - FOR EVERYTHING THAT COMES NEXT, EGO IS THE ENEMY . . . > Page 209 · Location 2501
# Highlight(yellow) - EPILOGUE > Page 212 · Location 2526
# Highlight(yellow) - EPILOGUE > Page 216 · Location 2578

# %%
a = np.array([1,2,3,4])
b = np.array([3,4,5,6])

# %%
pd.DataFrame(np.vstack([a,b]))
# Out:
#    0  1  2  3
# 0  1  2  3  4
# 1  3  4  5  6

# %%
c = [12,3,4,5]

# %%
c.append(5)

# %%
c.append([5,6])

# %%
c.extend([5,6])

# %%
c
# Out:
# [12, 3, 4, 5, 5, [5, 6], 5, 6]

# %%
# Out:
# 1

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html PUBLIC
# "-//W3C//DTD XHTML 1.0 Strict//EN"
# "XHTML1-s.dtd" >
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/TR/1999/REC-html-in-xml">
#  <head>
#   <meta charset="utf-8"/>
#   <style>
#    .bodyContainer {
#             font-family: Arial, Helvetica, sans-serif;
#             text-align: center;
#             padding-left: 32px;
#             padding-right: 32px;
#         }
#
#         .notebookFor {
#             font-size: 18px;
#             font-weight: 700;
#             text-align: center;
#             color: rgb(119, 119, 119);
#             margin: 24px 0px 0px;
#             padding: 0px;
#         }
#
#         .bookTitle {
#             font-size: 24px;
#             font-weight: 700;
#             text-align: center;
#             color: #333333;
#             margin-top: 22px;
#             padding: 0px;
#         }
#
#         .authors {
#             font-size: 18px;
#             font-weight: 700;
#             text-align: center;
#             color: rgb(119, 119, 119);
#             margin-top: 22px;
#             margin-bottom: 24px;
#             padding: 0px;
#         }
#
#         .citation {
#             font-size: 18px;
#             font-weight: 500;
#             text-align: center;
#             color: #333333;
#             margin-top: 22px;
#             margin-bottom: 24px;
#             padding: 0px;
#         }
#
#         .sectionHeading {
#             font-size: 24px;
#             font-weight: 700;
#             text-align: left;
#             color: #333333;
#             margin-top: 24px;
#             padding: 0px;
#         }
#
#         .noteHeading {
#             font-size: 18px;
#             font-weight: 700;
#             text-align: left;
#             color: #333333;
#             margin-top: 20px;
#             padding: 0px;
#         }
#
#         .noteText {
#             font-size: 18px;
#             font-weight: 500;
#             text-align: left;
#             color: #333333;
#             margin: 2px 0px 0px;
#             padding: 0px;
#         }
#
#         .highlight_blue {
#             color: rgb(178, 205, 251);
#         }
#
#         .highlight_orange {
#             color: #ffd7ae;
#         }
#
#         .highlight_pink {
#             color: rgb(255, 191, 206);
#         }
#
#         .highlight_yellow {
#             color: rgb(247, 206, 0);
#         }
#
#         .notebookGraphic {
#             margin-top: 10px;
#             text-align: left;
#         }
#
#         .notebookGraphic img {
#             -o-box-shadow:      0px 0px 5px #888;
#             -icab-box-shadow:   0px 0px 5px #888;
#             -khtml-box-shadow:  0px 0px 5px #888;
#             -moz-box-shadow:    0px 0px 5px #888;
#             -webkit-box-shadow: 0px 0px 5px #888;
#             box-shadow:         0px 0px 5px #888;
#             max-width: 100%;
#             height: auto;
#         }
#
#         hr {
#             border: 0px none;
#             height: 1px;
#             background: none repeat scroll 0% 0% rgb(221, 221, 221);
#         }
#   </style>
#   <script>
#   </script>
#  </head>
#  <body>
#   <div class="bodyContainer">
#    <div class="notebookFor">
#     Notebook Export
#    </div>
#    <div class="bookTitle">
#     Can't Hurt Me: Master Your Mind and Defy the Odds
#    </div>
#    <div class="authors">
#     Goggins, David
#    </div>
#    <div class="citation">
#    </div>
#    <hr/>
#    <div class="sectionHeading">
#     Introduction
#    </div>
#    <div class="noteHeading">
#     Highlight(
#     <span class="highlight_yellow">
#      yellow
#     </span>
#     ) - Page 13 · Location 64
#    </div>
#    <div class="noteText">
#     Heraclitus, a philosopher born in the Persian Empire back in the fifth century BC, had it right when he wrote about men on the battlefield. “Out of every one hundred men,” he wrote, “ten shouldn’t even be there, eighty are just targets, nine are the real fighters, and we are lucky to have them, for they make the battle. Ah, but the one, one is a warrior…”
#    </div>
#    <div class="noteHeading">
#     Highlight(
#     <span class="highlight_yellow">
#      yellow
#     </span>
#     ) - Page 13 · Location 67
#    </div>
#    <div class="noteText">
#     From the time you take your first breath, you become eligible to die. You also become eligible to find your greatness and become the One Warrior. But it is up to you to equip yourself for the battle ahead. Only you can master your mind, which is what it takes to live a bold life filled with accomplishments most people consider beyond their capability.
#    </div>
#    <div class="sectionHeading">
#     2. Truth Hurts
#    </div>
#    <div class="noteHeading">
#     Highlight(
#     <span class="highlight_yellow">
#      yellow
#     </span>
#     ) - Page 70 · Location 822
#    </div>
#    <div class="noteText">
#     From then on, I brainwashed myself into craving discomfort. If it was raining, I would go run. Whenever it started snowing, my mind would say, Get your fucking running shoes on. Sometimes I wussed out and had to deal with it at the Accountability Mirror. But facing that mirror, facing myself, motivated me to fight through uncomfortable experiences, and, as a result, I became tougher. And being tough and resilient helped me meet my goals. Nothing
#    </div>
#    <div class="noteHeading">
#     Highlight(
#     <span class="highlight_yellow">
#      yellow
#     </span>
#     ) - Page 72 · Location 848
#    </div>
#    <div class="noteText">
#     By the time I graduated, I knew that the confidence I’d managed to develop didn’t come from a perfect family or God-given talent. It came from personal accountability which brought me self respect, and self respect will always light a way forward.
#    </div>
#    <div class="noteHeading">
#     Bookmark - Page 73 · Location 855
#    </div>
#    <div class="sectionHeading">
#     3. The Impossible Task
#    </div>
#    <div class="noteHeading">
#     Highlight(
#     <span class="highlight_yellow">
#      yellow
#     </span>
#     ) - Page 87 · Location 1041
#    </div>
#    <div class="noteText">
#     “In a society where mediocrity is too often the standard and too often rewarded,” he said, “there is intense fascination with men who detest mediocrity, who refuse to define themselves in conventional terms, and who seek to transcend traditionally recognized human capabilities. This is exactly the type of person BUD/ S is meant to find. The man who finds a way to complete each and every task to the best of his ability. The man who will adapt and overcome any and all obstacles.”
#    </div>
#    <div class="sectionHeading">
#     4. Taking Souls
#    </div>
#    <div class="noteHeading">
#     Highlight(
#     <span class="highlight_yellow">
#      yellow
#     </span>
#     ) - Page 114 · Location 1412
#    </div>
#    <div class="noteText">
#     Everything in life is a mind game! Whenever we get swept under by life’s dramas, large and small, we are forgetting that no matter how bad the pain gets, no matter how harrowing the torture, all bad things end. That forgetting happens the second we give control over our emotions and actions to other people, which can easily happen when pain is peaking.
#    </div>
#    <div class="sectionHeading">
#     5. Armored Mind
#    </div>
#    <div class="noteHeading">
#     Highlight(
#     <span class="highlight_yellow">
#      yellow
#     </span>
#     ) - Page 141 · Location 1791
#    </div>
#    <div class="noteText">
#     The reason it’s important to push hardest when you want to quit the most is because it helps you callous your mind. It’s the same reason why you have to do your best work when you are the least motivated. That’s why I loved PT in BUD/ S and why I still love it today. Physical challenges strengthen my mind so I’m ready for whatever life throws at me, and it will do the same for you.
#    </div>
#    <div class="sectionHeading">
#     8. Talent Not Required
#    </div>
#    <div class="noteHeading">
#     Highlight(
#     <span class="highlight_yellow">
#      yellow
#     </span>
#     ) - Page 249 · Location 3254
#    </div>
#    <div class="noteText">
#     Our culture has become hooked on the quick-fix, the life hack, efficiency. Everyone is on the hunt for that simple action algorithm that nets maximum profit with the least amount of effort. There’s no denying this attitude may get you some of the trappings of success, if you’re lucky, but it will not lead to a calloused mind or self-mastery. If you want to master the mind and remove your governor, you’ll have to become addicted to hard work. Because passion and obsession, even talent, are only useful tools if you have the work ethic to back them up.
#    </div>
#    <div class="noteHeading">
#     Highlight(
#     <span class="highlight_yellow">
#      yellow
#     </span>
#     ) - Page 256 · Location 3344
#    </div>
#    <div class="noteText">
#     The point is not to allow a setback to shatter our focus, or our detours to dictate our mindset. Always be ready to adjust, recalibrate, and stay after it to become better, somehow.
#    </div>
#    <div class="noteHeading">
#     Highlight(
#     <span class="highlight_yellow">
#      yellow
#     </span>
#     ) - Page 256 · Location 3346
#    </div>
#    <div class="noteText">
#     The sole reason I work out like I do isn’t to prepare for and win ultra races. I don’t have an athletic motive at all. It’s to prepare my mind for life itself. Life will always be the most grueling endurance sport, and when you train hard, get uncomfortable, and callous your mind, you will become a more versatile competitor, trained to find a way forward no matter what. Because there will be times when the shit life throws at you isn’t minor at all. Sometimes life hits you dead in the fucking heart.
#    </div>
#    <div class="sectionHeading">
#     9. Uncommon Amongst Uncommon
#    </div>
#    <div class="noteHeading">
#     Highlight(
#     <span class="highlight_yellow">
#      yellow
#     </span>
#     ) - Page 278 · Location 3630
#    </div>
#    <div class="noteText">
#     All of us can be the person who flies all day and night only to arrive home to a filthy house, and instead of blaming family or roommates, cleans it up right then because they refuse to ignore duties undone.
#    </div>
#    <div class="sectionHeading">
#     10. The Empowerment of Failure
#    </div>
#    <div class="noteHeading">
#     Highlight(
#     <span class="highlight_yellow">
#      yellow
#     </span>
#     ) - Page 324 · Location 4204
#    </div>
#    <div class="noteText">
#     That means checking yourself on how and what you were thinking during the preparation and execution phases of your failure.
#    </div>
#    <div class="sectionHeading">
#     11. What If?
#    </div>
#    <div class="noteHeading">
#     Highlight(
#     <span class="highlight_yellow">
#      yellow
#     </span>
#     ) - Page 352 · Location 4578
#    </div>
#    <div class="noteText">
#     The Buddha famously said that life is suffering. I’m not a Buddhist, but I know what he meant and so do you. To exist in this world, we must contend with humiliation, broken dreams, sadness, and loss. That’s just nature. Each specific life comes with its own personalized portion of pain. It’s coming for you. You can’t stop it. And you know it.
#    </div>
#   </div>
#  </body>
# </html>

# %%
print(soup.body)
# Out:
# <body>
# <div class="bodyContainer">
# <div class="notebookFor">
#                 Notebook Export
#             </div>
# <div class="bookTitle">
#                 Ego Is the Enemy
#             </div>
# <div class="authors">
#                 Holiday, Ryan
#             </div>
# <div class="citation">
# </div>
# <hr/>
# <div class="sectionHeading">
#     THE PAINFUL PROLOGUE
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_orange">orange</span>) - Page xxiv · Location 185
# </div>
# <div class="noteText">
#     We must begin by seeing ourselves and the world in a new way for the first time. Then we must fight to be different and fight to stay different—that’s the hard part. I’m not saying you should repress or crush every ounce of ego in your life—or that doing so is even possible. These are just reminders, moral stories to encourage our better impulses.
# </div><div class="sectionHeading">
#     INTRODUCTION
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_orange">orange</span>) - Page 2 · Location 210
# </div>
# <div class="noteText">
#     The ego we see most commonly goes by a more casual definition: an unhealthy belief in our own importance. Arrogance. Self-centered ambition.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - Page 4 · Location 238
# </div>
# <div class="noteText">
#     “If you start believing in your greatness, it is the death of your creativity.”
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - Page 6 · Location 266
# </div>
# <div class="noteText">
#     Humble in our aspirations Gracious in our success Resilient in our failures
# </div><div class="sectionHeading">
#     PART I: ASPIRE
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - TALK, TALK, TALK &gt; Page 26 · Location 457
# </div>
# <div class="noteText">
#     So what is scarce and rare? Silence. The ability to deliberately keep yourself out of the conversation and subsist without its validation. Silence is the respite of the confident and the strong.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - TALK, TALK, TALK &gt; Page 28 · Location 486
# </div>
# <div class="noteText">
#     The only relationship between work and chatter is that one kills the other.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - TO BE OR TO DO? &gt; Page 35 · Location 569
# </div>
# <div class="noteText">
#     Think about this the next time you face that choice: Do I need this? Or is it really about ego? Are you ready to make the right decision? Or do the prizes still glitter off in the distance? To be or to do—life is a constant roll call.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - BECOME A STUDENT &gt; Page 39 · Location 610
# </div>
# <div class="noteText">
#     mastery. The pretense of knowledge is our most dangerous vice, because it prevents us from getting any better. Studious self-assessment is the antidote.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - BECOME A STUDENT &gt; Page 39 · Location 615
# </div>
# <div class="noteText">
#     Each fighter, to become great, he said, needs to have someone better that they can learn from, someone lesser who they can teach, and someone equal that they can challenge themselves against.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - BECOME A STUDENT &gt; Page 43 · Location 662
# </div>
# <div class="noteText">
#     It’s why the old proverb says, “When student is ready, the teacher appears.”
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - DON’T BE PASSIONATE &gt; Page 47 · Location 705
# </div>
# <div class="noteText">
#     The reality: We hear what we want to hear. We do what we feel like doing, and despite being incredibly busy and working very hard, we accomplish very little. Or worse, find ourselves in a mess we never anticipated.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - DON’T BE PASSIONATE &gt; Page 48 · Location 715
# </div>
# <div class="noteText">
#     Passion typically masks a weakness. Its breathlessness and impetuousness and franticness are poor substitutes for discipline, for mastery, for strength and purpose and perseverance. You need to be able to spot this in others and in yourself, because while the origins of passion may be earnest and good, its effects are comical and then monstrous.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - DON’T BE PASSIONATE &gt; Page 49 · Location 728
# </div>
# <div class="noteText">
#     What humans require in our ascent is purpose and realism. Purpose, you could say, is like passion with boundaries. Realism is detachment and perspective.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - DON’T BE PASSIONATE &gt; Page 49 · Location 731
# </div>
# <div class="noteText">
#     Passion is about. (I am so passionate about ______.) Purpose is to and for. (I must do ______. I was put here to accomplish ______. I am willing to endure ______ for the sake of this.) Actually, purpose deemphasizes the I. Purpose is about pursuing something outside yourself as opposed to pleasuring yourself.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - DON’T BE PASSIONATE &gt; Page 50 · Location 744
# </div>
# <div class="noteText">
#     Passion is form over function. Purpose is function, function, function.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - FOLLOW THE CANVAS STRATEGY &gt; Page 51 · Location 751
# </div>
# <div class="noteText">
#     Great men have almost always shown themselves as ready to obey as they afterwards proved able to command.—LORD MAHON
# </div><div class="noteHeading">
#     Bookmark - FOLLOW THE CANVAS STRATEGY &gt; Page 53 · Location 777
# </div>
# <div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - FOLLOW THE CANVAS STRATEGY &gt; Page 53 · Location 783
# </div>
# <div class="noteText">
#     Find canvases for other people to paint on. Be an anteambulo. Clear the path for the people above you and you will eventually create a path for yourself.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - FOLLOW THE CANVAS STRATEGY &gt; Page 53 · Location 784
# </div>
# <div class="noteText">
#     When you are just starting out, we can be sure of a few fundamental realities: 1) You’re not nearly as good or as important as you think you are; 2) You have an attitude that needs to be readjusted; 3) Most of what you think you know or most of what you learned in books or in school is out of date or wrong.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - FOLLOW THE CANVAS STRATEGY &gt; Page 56 · Location 816
# </div>
# <div class="noteText">
#     Greatness comes from humble beginnings; it comes from grunt work. It means you’re the least important person in the room—until you change that with results.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - FOLLOW THE CANVAS STRATEGY &gt; Page 57 · Location 830
# </div>
# <div class="noteText">
#     Maybe it’s coming up with ideas to hand over to your boss. Find people, thinkers, up-and-comers to introduce them to each other. Cross wires to create new sparks. Find what nobody else wants to do and do it. Find inefficiencies and waste and redundancies. Identify leaks and patches to free up resources for new areas. Produce more than everyone else and give your ideas away
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - RESTRAIN YOURSELF &gt; Page 63 · Location 899
# </div>
# <div class="noteText">
#     Those who have subdued their ego understand that it doesn’t degrade you when others treat you poorly; it degrades them.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - RESTRAIN YOURSELF &gt; Page 64 · Location 913
# </div>
# <div class="noteText">
#     But you’re not able to change the system until after you’ve made it. In the meantime, you’ll have to find some way to make it suit your purposes—even if those purposes are just extra time to develop properly, to learn from others on their dime, to build your base and establish yourself.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - THE DANGER OF EARLY PRIDE &gt; Page 74 · Location 1022
# </div>
# <div class="noteText">
#     Pride blunts the very instrument we need to own in order to succeed: our mind. Our ability to learn, to adapt, to be flexible, to build relationships, all of this is dulled by pride.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - THE DANGER OF EARLY PRIDE &gt; Page 75 · Location 1039
# </div>
# <div class="noteText">
#     Pride is a masterful encroacher. John D. Rockefeller, as a young man, practiced a nightly conversation with himself. “Because you have got a start,” he’d say aloud or write in his diary, “you think you are quite a merchant; look out or you will lose your head—go steady.”
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - THE DANGER OF EARLY PRIDE &gt; Page 78 · Location 1076
# </div>
# <div class="noteText">
#     It isn’t “Don’t boast about what hasn’t happened yet.” It is more directly “Don’t boast.” There’s nothing in it for you.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - WORK, WORK, WORK &gt; Page 82 · Location 1120
# </div>
# <div class="noteText">
#     Fac, si facis. (Do it if you’re going to do it.)
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - WORK, WORK, WORK &gt; Page 83 · Location 1136
# </div>
# <div class="noteText">
#     Every time you sit down to work, remind yourself: I am delaying gratification by doing this. I am passing the marshmallow test. I am earning what my ambition burns for. I am making an investment in myself instead of in my ego. Give yourself a little credit for this choice, but not so much, because you’ve got to get back to the task at hand: practicing, working, improving.
# </div><div class="sectionHeading">
#     PART II: SUCCESS
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - Page 99 · Location 1267
# </div>
# <div class="noteText">
#     “Man is pushed by drives,” Viktor Frankl observed. “But he is pulled by values.” Ruled by or ruling? Which are you?
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - ALWAYS STAY A STUDENT &gt; Page 105 · Location 1334
# </div>
# <div class="noteText">
#     An amateur is defensive. The professional finds learning (and even, occasionally, being shown up) to be enjoyable; they like being challenged and humbled, and engage in education as an ongoing and endless process.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - DON’T TELL YOURSELF A STORY &gt; Page 111 · Location 1400
# </div>
# <div class="noteText">
#     When we are aspiring we must resist the impulse to reverse engineer success from other people’s stories. When we achieve our own, we must resist the desire to pretend that everything unfolded exactly as we’d planned. There was no grand narrative. You should remember—you were there when it happened.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - WHAT’S IMPORTANT TO YOU? &gt; Page 116 · Location 1455
# </div>
# <div class="noteText">
#     All of us waste precious life doing things we don’t like, to prove ourselves to people we don’t respect, and to get things we don’t want. Why do we do this? Well, it should
# </div><div class="noteHeading">
#     Bookmark - ENTITLEMENT, CONTROL, AND PARANOIA &gt; Page 122 · Location 1528
# </div>
# <div class="noteHeading">
#     Bookmark - MEDITATE ON THE IMMENSITY &gt; Page 141 · Location 1754
# </div>
# <div class="sectionHeading">
#     PART III: FAILURE
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - Page 165 · Location 1996
# </div>
# <div class="noteText">
#     Ego loves this notion, the idea that something is “fair” or not. Psychologists call it narcissistic injury when we take personally totally indifferent and objective events. We do that when our sense of self is fragile and dependent on life going our way all the time. Whether what you’re going through is your fault or your problem doesn’t matter, because it’s yours to deal with right now.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - Page 168 · Location 2037
# </div>
# <div class="noteText">
#     The only way out is through.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - ALIVE TIME OR DEAD TIME? &gt; Page 173 · Location 2081
# </div>
# <div class="noteText">
#     Dead time is revived when we use it as an opportunity to do what we’ve long needed to do.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - THE EFFORT IS ENOUGH &gt; Page 177 · Location 2132
# </div>
# <div class="noteText">
#     Doing the right thing was enough. Serving his country, his God, and doing his duty faithfully was all that mattered. Any adversity could be endured and any rewards were considered extra.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - THE EFFORT IS ENOUGH &gt; Page 178 · Location 2145
# </div>
# <div class="noteText">
#     It’s far better when doing good work is sufficient. In other words, the less attached we are to outcomes the better. When fulfilling our own standards is what fills us with pride and self-respect. When the effort—not the results, good or bad—is enough.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - Fight Club MOMENTS &gt; Page 184 · Location 2215
# </div>
# <div class="noteText">
#     1. They almost always came at the hands of some outside force or person. 2. They often involved things we already knew about ourselves, but were too scared to admit. 3. From the ruin came the opportunity for great progress and improvement.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - DRAW THE LINE &gt; Page 192 · Location 2306
# </div>
# <div class="noteText">
#     “If you cannot reasonably hope for a favorable extrication, do not plunge deeper. Have the courage to make a full stop.”
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - DRAW THE LINE &gt; Page 193 · Location 2331
# </div>
# <div class="noteText">
#     “He who fears death will never do anything worthy of a living man,” Seneca once said. Alter that: He who will do anything to avoid failure will almost certainly do something worthy of a failure.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - ALWAYS LOVE &gt; Page 205 · Location 2461
# </div>
# <div class="noteText">
#     The question we must ask for ourselves is: Are we going to be miserable just because other people are?
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - FOR EVERYTHING THAT COMES NEXT, EGO IS THE ENEMY . . . &gt; Page 209 · Location 2501
# </div>
# <div class="noteText">
#     Aspiration leads to success (and adversity). Success creates its own adversity (and, hopefully, new ambitions). And adversity leads to aspiration and more success. It’s an endless loop.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - EPILOGUE &gt; Page 212 · Location 2526
# </div>
# <div class="noteText">
#     training was like sweeping the floor. Just because we’ve done it once, doesn’t mean the floor is clean forever. Every day the dust comes back. Every day we must sweep. The same is true for ego. You would be stunned at what kind of damage dust and dirt can do over time. And how quickly it accumulates and becomes utterly unmanageable.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - EPILOGUE &gt; Page 216 · Location 2578
# </div>
# <div class="noteText">
#     There’s a quote from Bismarck that says, in effect, any fool can learn from experience. The trick is to learn from other people’s experience.
# </div>
# </div>
# </body>

# %%
print(soup.find_all('div', class_='noteHeading'))
# Out:
# [<div class="noteHeading">
#     Highlight() - Page xxiv · Location 185
# </div>, <div class="noteHeading">
#     Highlight(<span class="highlight_orange">orange</span>) - Page 2 · Location 210
# </div>, <div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - Page 4 · Location 238
# </div>, <div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - Page 6 · Location 266
# </div>, <div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - TALK, TALK, TALK &gt; Page 26 · Location 457
# </div>, <div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - TALK, TALK, TALK &gt; Page 28 · Location 486
# </div>, <div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - TO BE OR TO DO? &gt; Page 35 · Location 569
# </div>, <div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - BECOME A STUDENT &gt; Page 39 · Location 610
# </div>, <div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - BECOME A STUDENT &gt; Page 39 · Location 615
# </div>, <div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - BECOME A STUDENT &gt; Page 43 · Location 662
# </div>, <div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - DON’T BE PASSIONATE &gt; Page 47 · Location 705
# </div>, <div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - DON’T BE PASSIONATE &gt; Page 48 · Location 715
# </div>, <div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - DON’T BE PASSIONATE &gt; Page 49 · Location 728
# </div>, <div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - DON’T BE PASSIONATE &gt; Page 49 · Location 731
# </div>, <div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - DON’T BE PASSIONATE &gt; Page 50 · Location 744
# </div>, <div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - FOLLOW THE CANVAS STRATEGY &gt; Page 51 · Location 751
# </div>, <div class="noteHeading">
#     Bookmark - FOLLOW THE CANVAS STRATEGY &gt; Page 53 · Location 777
# </div>, <div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - FOLLOW THE CANVAS STRATEGY &gt; Page 53 · Location 783
# </div>, <div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - FOLLOW THE CANVAS STRATEGY &gt; Page 53 · Location 784
# </div>, <div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - FOLLOW THE CANVAS STRATEGY &gt; Page 56 · Location 816
# </div>, <div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - FOLLOW THE CANVAS STRATEGY &gt; Page 57 · Location 830
# </div>, <div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - RESTRAIN YOURSELF &gt; Page 63 · Location 899
# </div>, <div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - RESTRAIN YOURSELF &gt; Page 64 · Location 913
# </div>, <div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - THE DANGER OF EARLY PRIDE &gt; Page 74 · Location 1022
# </div>, <div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - THE DANGER OF EARLY PRIDE &gt; Page 75 · Location 1039
# </div>, <div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - THE DANGER OF EARLY PRIDE &gt; Page 78 · Location 1076
# </div>, <div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - WORK, WORK, WORK &gt; Page 82 · Location 1120
# </div>, <div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - WORK, WORK, WORK &gt; Page 83 · Location 1136
# </div>, <div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - Page 99 · Location 1267
# </div>, <div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - ALWAYS STAY A STUDENT &gt; Page 105 · Location 1334
# </div>, <div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - DON’T TELL YOURSELF A STORY &gt; Page 111 · Location 1400
# </div>, <div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - WHAT’S IMPORTANT TO YOU? &gt; Page 116 · Location 1455
# </div>, <div class="noteHeading">
#     Bookmark - ENTITLEMENT, CONTROL, AND PARANOIA &gt; Page 122 · Location 1528
# </div>, <div class="noteHeading">
#     Bookmark - MEDITATE ON THE IMMENSITY &gt; Page 141 · Location 1754
# </div>, <div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - Page 165 · Location 1996
# </div>, <div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - Page 168 · Location 2037
# </div>, <div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - ALIVE TIME OR DEAD TIME? &gt; Page 173 · Location 2081
# </div>, <div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - THE EFFORT IS ENOUGH &gt; Page 177 · Location 2132
# </div>, <div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - THE EFFORT IS ENOUGH &gt; Page 178 · Location 2145
# </div>, <div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - Fight Club MOMENTS &gt; Page 184 · Location 2215
# </div>, <div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - DRAW THE LINE &gt; Page 192 · Location 2306
# </div>, <div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - DRAW THE LINE &gt; Page 193 · Location 2331
# </div>, <div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - ALWAYS LOVE &gt; Page 205 · Location 2461
# </div>, <div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - FOR EVERYTHING THAT COMES NEXT, EGO IS THE ENEMY . . . &gt; Page 209 · Location 2501
# </div>, <div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - EPILOGUE &gt; Page 212 · Location 2526
# </div>, <div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - EPILOGUE &gt; Page 216 · Location 2578
# </div>]

# %%
s_tag = soup.span

# %%
s_tag.decomposed()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-02acbc8486d6> in <module>
# ----> 1 s_tag.decomposed()
#
# TypeError: 'NoneType' object is not callable

# %%
print(soup.body)
# Out:
# <body>
# <div class="bodyContainer">
# <div class="notebookFor">
#                 Notebook Export
#             </div>
# <div class="bookTitle">
#                 Ego Is the Enemy
#             </div>
# <div class="authors">
#                 Holiday, Ryan
#             </div>
# <div class="citation">
# </div>
# <hr/>
# <div class="sectionHeading">
#     THE PAINFUL PROLOGUE
# </div><div class="noteHeading">
#     Highlight() - Page xxiv · Location 185
# </div>
# <div class="noteText">
#     We must begin by seeing ourselves and the world in a new way for the first time. Then we must fight to be different and fight to stay different—that’s the hard part. I’m not saying you should repress or crush every ounce of ego in your life—or that doing so is even possible. These are just reminders, moral stories to encourage our better impulses.
# </div><div class="sectionHeading">
#     INTRODUCTION
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_orange">orange</span>) - Page 2 · Location 210
# </div>
# <div class="noteText">
#     The ego we see most commonly goes by a more casual definition: an unhealthy belief in our own importance. Arrogance. Self-centered ambition.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - Page 4 · Location 238
# </div>
# <div class="noteText">
#     “If you start believing in your greatness, it is the death of your creativity.”
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - Page 6 · Location 266
# </div>
# <div class="noteText">
#     Humble in our aspirations Gracious in our success Resilient in our failures
# </div><div class="sectionHeading">
#     PART I: ASPIRE
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - TALK, TALK, TALK &gt; Page 26 · Location 457
# </div>
# <div class="noteText">
#     So what is scarce and rare? Silence. The ability to deliberately keep yourself out of the conversation and subsist without its validation. Silence is the respite of the confident and the strong.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - TALK, TALK, TALK &gt; Page 28 · Location 486
# </div>
# <div class="noteText">
#     The only relationship between work and chatter is that one kills the other.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - TO BE OR TO DO? &gt; Page 35 · Location 569
# </div>
# <div class="noteText">
#     Think about this the next time you face that choice: Do I need this? Or is it really about ego? Are you ready to make the right decision? Or do the prizes still glitter off in the distance? To be or to do—life is a constant roll call.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - BECOME A STUDENT &gt; Page 39 · Location 610
# </div>
# <div class="noteText">
#     mastery. The pretense of knowledge is our most dangerous vice, because it prevents us from getting any better. Studious self-assessment is the antidote.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - BECOME A STUDENT &gt; Page 39 · Location 615
# </div>
# <div class="noteText">
#     Each fighter, to become great, he said, needs to have someone better that they can learn from, someone lesser who they can teach, and someone equal that they can challenge themselves against.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - BECOME A STUDENT &gt; Page 43 · Location 662
# </div>
# <div class="noteText">
#     It’s why the old proverb says, “When student is ready, the teacher appears.”
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - DON’T BE PASSIONATE &gt; Page 47 · Location 705
# </div>
# <div class="noteText">
#     The reality: We hear what we want to hear. We do what we feel like doing, and despite being incredibly busy and working very hard, we accomplish very little. Or worse, find ourselves in a mess we never anticipated.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - DON’T BE PASSIONATE &gt; Page 48 · Location 715
# </div>
# <div class="noteText">
#     Passion typically masks a weakness. Its breathlessness and impetuousness and franticness are poor substitutes for discipline, for mastery, for strength and purpose and perseverance. You need to be able to spot this in others and in yourself, because while the origins of passion may be earnest and good, its effects are comical and then monstrous.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - DON’T BE PASSIONATE &gt; Page 49 · Location 728
# </div>
# <div class="noteText">
#     What humans require in our ascent is purpose and realism. Purpose, you could say, is like passion with boundaries. Realism is detachment and perspective.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - DON’T BE PASSIONATE &gt; Page 49 · Location 731
# </div>
# <div class="noteText">
#     Passion is about. (I am so passionate about ______.) Purpose is to and for. (I must do ______. I was put here to accomplish ______. I am willing to endure ______ for the sake of this.) Actually, purpose deemphasizes the I. Purpose is about pursuing something outside yourself as opposed to pleasuring yourself.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - DON’T BE PASSIONATE &gt; Page 50 · Location 744
# </div>
# <div class="noteText">
#     Passion is form over function. Purpose is function, function, function.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - FOLLOW THE CANVAS STRATEGY &gt; Page 51 · Location 751
# </div>
# <div class="noteText">
#     Great men have almost always shown themselves as ready to obey as they afterwards proved able to command.—LORD MAHON
# </div><div class="noteHeading">
#     Bookmark - FOLLOW THE CANVAS STRATEGY &gt; Page 53 · Location 777
# </div>
# <div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - FOLLOW THE CANVAS STRATEGY &gt; Page 53 · Location 783
# </div>
# <div class="noteText">
#     Find canvases for other people to paint on. Be an anteambulo. Clear the path for the people above you and you will eventually create a path for yourself.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - FOLLOW THE CANVAS STRATEGY &gt; Page 53 · Location 784
# </div>
# <div class="noteText">
#     When you are just starting out, we can be sure of a few fundamental realities: 1) You’re not nearly as good or as important as you think you are; 2) You have an attitude that needs to be readjusted; 3) Most of what you think you know or most of what you learned in books or in school is out of date or wrong.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - FOLLOW THE CANVAS STRATEGY &gt; Page 56 · Location 816
# </div>
# <div class="noteText">
#     Greatness comes from humble beginnings; it comes from grunt work. It means you’re the least important person in the room—until you change that with results.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - FOLLOW THE CANVAS STRATEGY &gt; Page 57 · Location 830
# </div>
# <div class="noteText">
#     Maybe it’s coming up with ideas to hand over to your boss. Find people, thinkers, up-and-comers to introduce them to each other. Cross wires to create new sparks. Find what nobody else wants to do and do it. Find inefficiencies and waste and redundancies. Identify leaks and patches to free up resources for new areas. Produce more than everyone else and give your ideas away
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - RESTRAIN YOURSELF &gt; Page 63 · Location 899
# </div>
# <div class="noteText">
#     Those who have subdued their ego understand that it doesn’t degrade you when others treat you poorly; it degrades them.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - RESTRAIN YOURSELF &gt; Page 64 · Location 913
# </div>
# <div class="noteText">
#     But you’re not able to change the system until after you’ve made it. In the meantime, you’ll have to find some way to make it suit your purposes—even if those purposes are just extra time to develop properly, to learn from others on their dime, to build your base and establish yourself.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - THE DANGER OF EARLY PRIDE &gt; Page 74 · Location 1022
# </div>
# <div class="noteText">
#     Pride blunts the very instrument we need to own in order to succeed: our mind. Our ability to learn, to adapt, to be flexible, to build relationships, all of this is dulled by pride.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - THE DANGER OF EARLY PRIDE &gt; Page 75 · Location 1039
# </div>
# <div class="noteText">
#     Pride is a masterful encroacher. John D. Rockefeller, as a young man, practiced a nightly conversation with himself. “Because you have got a start,” he’d say aloud or write in his diary, “you think you are quite a merchant; look out or you will lose your head—go steady.”
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - THE DANGER OF EARLY PRIDE &gt; Page 78 · Location 1076
# </div>
# <div class="noteText">
#     It isn’t “Don’t boast about what hasn’t happened yet.” It is more directly “Don’t boast.” There’s nothing in it for you.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - WORK, WORK, WORK &gt; Page 82 · Location 1120
# </div>
# <div class="noteText">
#     Fac, si facis. (Do it if you’re going to do it.)
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - WORK, WORK, WORK &gt; Page 83 · Location 1136
# </div>
# <div class="noteText">
#     Every time you sit down to work, remind yourself: I am delaying gratification by doing this. I am passing the marshmallow test. I am earning what my ambition burns for. I am making an investment in myself instead of in my ego. Give yourself a little credit for this choice, but not so much, because you’ve got to get back to the task at hand: practicing, working, improving.
# </div><div class="sectionHeading">
#     PART II: SUCCESS
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - Page 99 · Location 1267
# </div>
# <div class="noteText">
#     “Man is pushed by drives,” Viktor Frankl observed. “But he is pulled by values.” Ruled by or ruling? Which are you?
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - ALWAYS STAY A STUDENT &gt; Page 105 · Location 1334
# </div>
# <div class="noteText">
#     An amateur is defensive. The professional finds learning (and even, occasionally, being shown up) to be enjoyable; they like being challenged and humbled, and engage in education as an ongoing and endless process.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - DON’T TELL YOURSELF A STORY &gt; Page 111 · Location 1400
# </div>
# <div class="noteText">
#     When we are aspiring we must resist the impulse to reverse engineer success from other people’s stories. When we achieve our own, we must resist the desire to pretend that everything unfolded exactly as we’d planned. There was no grand narrative. You should remember—you were there when it happened.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - WHAT’S IMPORTANT TO YOU? &gt; Page 116 · Location 1455
# </div>
# <div class="noteText">
#     All of us waste precious life doing things we don’t like, to prove ourselves to people we don’t respect, and to get things we don’t want. Why do we do this? Well, it should
# </div><div class="noteHeading">
#     Bookmark - ENTITLEMENT, CONTROL, AND PARANOIA &gt; Page 122 · Location 1528
# </div>
# <div class="noteHeading">
#     Bookmark - MEDITATE ON THE IMMENSITY &gt; Page 141 · Location 1754
# </div>
# <div class="sectionHeading">
#     PART III: FAILURE
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - Page 165 · Location 1996
# </div>
# <div class="noteText">
#     Ego loves this notion, the idea that something is “fair” or not. Psychologists call it narcissistic injury when we take personally totally indifferent and objective events. We do that when our sense of self is fragile and dependent on life going our way all the time. Whether what you’re going through is your fault or your problem doesn’t matter, because it’s yours to deal with right now.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - Page 168 · Location 2037
# </div>
# <div class="noteText">
#     The only way out is through.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - ALIVE TIME OR DEAD TIME? &gt; Page 173 · Location 2081
# </div>
# <div class="noteText">
#     Dead time is revived when we use it as an opportunity to do what we’ve long needed to do.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - THE EFFORT IS ENOUGH &gt; Page 177 · Location 2132
# </div>
# <div class="noteText">
#     Doing the right thing was enough. Serving his country, his God, and doing his duty faithfully was all that mattered. Any adversity could be endured and any rewards were considered extra.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - THE EFFORT IS ENOUGH &gt; Page 178 · Location 2145
# </div>
# <div class="noteText">
#     It’s far better when doing good work is sufficient. In other words, the less attached we are to outcomes the better. When fulfilling our own standards is what fills us with pride and self-respect. When the effort—not the results, good or bad—is enough.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - Fight Club MOMENTS &gt; Page 184 · Location 2215
# </div>
# <div class="noteText">
#     1. They almost always came at the hands of some outside force or person. 2. They often involved things we already knew about ourselves, but were too scared to admit. 3. From the ruin came the opportunity for great progress and improvement.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - DRAW THE LINE &gt; Page 192 · Location 2306
# </div>
# <div class="noteText">
#     “If you cannot reasonably hope for a favorable extrication, do not plunge deeper. Have the courage to make a full stop.”
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - DRAW THE LINE &gt; Page 193 · Location 2331
# </div>
# <div class="noteText">
#     “He who fears death will never do anything worthy of a living man,” Seneca once said. Alter that: He who will do anything to avoid failure will almost certainly do something worthy of a failure.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - ALWAYS LOVE &gt; Page 205 · Location 2461
# </div>
# <div class="noteText">
#     The question we must ask for ourselves is: Are we going to be miserable just because other people are?
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - FOR EVERYTHING THAT COMES NEXT, EGO IS THE ENEMY . . . &gt; Page 209 · Location 2501
# </div>
# <div class="noteText">
#     Aspiration leads to success (and adversity). Success creates its own adversity (and, hopefully, new ambitions). And adversity leads to aspiration and more success. It’s an endless loop.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - EPILOGUE &gt; Page 212 · Location 2526
# </div>
# <div class="noteText">
#     training was like sweeping the floor. Just because we’ve done it once, doesn’t mean the floor is clean forever. Every day the dust comes back. Every day we must sweep. The same is true for ego. You would be stunned at what kind of damage dust and dirt can do over time. And how quickly it accumulates and becomes utterly unmanageable.
# </div><div class="noteHeading">
#     Highlight(<span class="highlight_yellow">yellow</span>) - EPILOGUE &gt; Page 216 · Location 2578
# </div>
# <div class="noteText">
#     There’s a quote from Bismarck that says, in effect, any fool can learn from experience. The trick is to learn from other people’s experience.
# </div>
# </div>
# </body>

# %%
x = 0

div_tag = soup.find('div')
section = 0

section_headers = pd.DataFrame()
section_texts = pd.DataFrame()

current_type = None
current_page = None
current_location = None

while (x < 10):
    
    print(div_tag['class'][0])
    
    if div_tag['class'][0] == 'sectionHeading':
        print('hi')

        section += 1
        header = pd.Series([section, div_tag.text.strip()], index = ['Section', 'Text'])
        
        section_headers = pd.concat([section_headers, header], axis = 1)
        
        try:
            print('stop')
            div_tag = div_tag.find_next()
        except:
            print('stop')
            break
    
    if div_tag['class'][0] == 'noteHeading':
        
        div_text = div.text.strip() #get text of div
        page_location = get_page_location(div_text) #extract page & location
        
        current_type = page_location['Type']
        current_page = page_location['Page']
        current_location = page_location['Location']
        
        try:
            div_tag = div_tag.find_next()
        except:
            print('stop')
            break
        
    if div_tag['class'][0] == 'noteText':
        text = pd.Series([current_type, div_tag.text.strip(), current_page, current_location],
                        index = ['Type', 'Text', 'Page', 'Location'])
        section_texts = pd.concat([section_texts, text], axis = 1)
        
        try:
            div_tag = div_tag.find_next()
        except:
            print('stop')
            break
    
    try:
        div_tag = div_tag.find_next()
    except:
        break
            

    x+=1
# Out:
# bodyContainer
# notebookFor
# bookTitle
# authors
# citation
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-239-4540a44d6c86> in <module>
#      13 while (x < 10):
#      14
# ---> 15     print(div_tag['class'][0])
#      16
#      17     if div_tag['class'][0] == 'sectionHeading':
#
# ~\AppData\Local\Continuum\anaconda3\envs\[Lance]\lib\site-packages\bs4\element.py in __getitem__(self, key)
#     990         """tag[key] returns the value of the 'key' attribute for the tag,
#     991         and throws an exception if it's not there."""
# --> 992         return self.attrs[key]
#     993
#     994     def __iter__(self):
#
# KeyError: 'class'
